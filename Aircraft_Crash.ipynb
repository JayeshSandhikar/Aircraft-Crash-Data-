# %%
import csv
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df1=pd.read_csv('plane_crash_data.csv')

# %%
df1
# Out:
#                     date     time                            location  \
# 0     September 17, 1908    17:18                 Fort Myer, Virginia
# 1     September 07, 1909        ?             Juvisy-sur-Orge, France
# 2          July 12, 1912    06:30           Atlantic City, New Jersey
# 3        August 06, 1913        ?  Victoria, British Columbia, Canada
# 4     September 09, 1913  c 18:30                  Over the North Sea
# ...                  ...      ...                                 ...
# 5237  September 28, 2018     1010                   Chuuk, Micronesia
# 5238    October 29, 2018     0631              Off Jakarta, Indonesia
# 5239   November 06, 2018     0253                  Georgetown, Guyana
# 5240   November 18, 2018     2300           Near Mandan, North Dakota
# 5241    January 14, 2019     0830                         Karaj, Iran
#
#                            operator flight_number                     route  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5242 entries, 0 to 5241
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           5242 non-null   object
#  1   time           5242 non-null   object
#  2   location       5242 non-null   object
#  3   operator       5242 non-null   object
#  4   flight_number  5242 non-null   object
#  5   route          5242 non-null   object
#  6   aircraft_type  5242 non-null   object
#  7   registration   5242 non-null   object
#  8   cn_ln          5242 non-null   object
#  9   aboard         5242 non-null   object
#  10  fatalities     5242 non-null   object
#  11  ground         5242 non-null   object
#  12  summary        5242 non-null   object
# dtypes: object(13)
# memory usage: 532.5+ KB

# %%
df1.describe()
# Out:
#                       date  time        location  operator flight_number  \
# count                 5242  5242            5242      5242          5242
# unique                4742  1287            4327      2633           808
# top     September 11, 2001     ?  Moscow, Russia  Aeroflot             ?
# freq                     4  1917              16       217          4043
#
#        route aircraft_type registration cn_ln                      aboard  \
# count   5242          5242         5242  5242                        5242
# unique  3529          2557         4888  3781                         982
# top        ?  Douglas DC-3            ?     ?  2   (passengers:0  crew:2)
# freq    1338           310          321  1092                         224
#
#                         fatalities ground summary
# count                         5242   5242    5242
# unique                         871     52    4876
# top     1   (passengers:0  crew:1)      0       ?
# ...

# %%
df1.head()
# Out:
#                  date     time                            location  \
# 0  September 17, 1908    17:18                 Fort Myer, Virginia
# 1  September 07, 1909        ?             Juvisy-sur-Orge, France
# 2       July 12, 1912    06:30           Atlantic City, New Jersey
# 3     August 06, 1913        ?  Victoria, British Columbia, Canada
# 4  September 09, 1913  c 18:30                  Over the North Sea
#
#                  operator flight_number          route  \
# 0    Military - U.S. Army             ?  Demonstration
# 1                       ?             ?       Air show
# 2    Military - U.S. Navy             ?    Test flight
# 3                 Private             ?              ?
# 4  Military - German Navy             ?              ?
#
#             aircraft_type registration cn_ln                       aboard  \
# 0        Wright Flyer III            ?     1   2   (passengers:1  crew:1)
# 1          Wright Byplane          SC1     ?   1   (passengers:0  crew:1)
# ...

# %%
df1.tail()
# Out:
#                     date  time                   location  \
# 5237  September 28, 2018  1010          Chuuk, Micronesia
# 5238    October 29, 2018  0631     Off Jakarta, Indonesia
# 5239   November 06, 2018  0253         Georgetown, Guyana
# 5240   November 18, 2018  2300  Near Mandan, North Dakota
# 5241    January 14, 2019  0830                Karaj, Iran
#
#                            operator flight_number                     route  \
# 5237                    Air Niugini             ?           Pohnpei - Chuuk
# 5238                       Lion Air           610  Jakarta - Pangkal Pinang
# 5239            Fly Jamaica Airways             ?      Georgetown - Toronto
# 5240  Metro Area Ambulance Services             ?   Bismark - Sloulin Field
# 5241                       Saha Air             ?           Bishkek - Payam
#
#                aircraft_type registration       cn_ln  \
# 5237          Boeing 737-8BK       P2-PXE  33024/1688
# ...

# %%
Row_Col_Info=df1.shape

# %%
print("Rows are ", Row_Col_Info[0] ,"Column are ", Row_Col_Info[1])
# Out:
# Rows are  5242 Column are  13

# %%
# Now we will see another

# %%
df1.isnull().sum()
# Out:
# date             0
# time             0
# location         0
# operator         0
# flight_number    0
# route            0
# aircraft_type    0
# registration     0
# cn_ln            0
# aboard           0
# fatalities       0
# ground           0
# summary          0
# dtype: int64

# %%
df1.isnull().sum(axis=0)
# Out:
# date             0
# time             0
# location         0
# operator         0
# flight_number    0
# route            0
# aircraft_type    0
# registration     0
# cn_ln            0
# aboard           0
# fatalities       0
# ground           0
# summary          0
# dtype: int64

# %%
df1.describe()
# Out:
#                       date  time        location  operator flight_number  \
# count                 5242  5242            5242      5242          5242
# unique                4742  1287            4327      2633           808
# top     September 11, 2001     ?  Moscow, Russia  Aeroflot             ?
# freq                     4  1917              16       217          4043
#
#        route aircraft_type registration cn_ln                      aboard  \
# count   5242          5242         5242  5242                        5242
# unique  3529          2557         4888  3781                         982
# top        ?  Douglas DC-3            ?     ?  2   (passengers:0  crew:2)
# freq    1338           310          321  1092                         224
#
#                         fatalities ground summary
# count                         5242   5242    5242
# unique                         871     52    4876
# top     1   (passengers:0  crew:1)      0       ?
# ...

# %%
df1['operator'].unique()
# Out:
# array(['Military - U.S. Army', '?', 'Military - U.S. Navy', ...,
#        'Fly Jamaica Airways', 'Metro Area Ambulance Services', 'Saha Air'],
#       dtype=object)

# %%
df1['operator'].nunique()
# Out:
# 2633

# %%
df1['fatalities'].nunique()
# Out:
# 871

# %%
df1['location'].nunique()
# Out:
# 4327

# %%
df1[df1['operator'] == 'Lion Air']
# Out:
#                    date   time                location  operator  \
# 4695  November 30, 2004  18:14         Solo, Indonesia  Lion Air
# 5104     April 13, 2013  15:35     Denpasar, Indonesia  Lion Air
# 5238   October 29, 2018   0631  Off Jakarta, Indonesia  Lion Air
#
#      flight_number                                 route  \
# 4695           583  Jakarta, Indonesia - Solo, Indonesia
# 5104           904                    Bandung - Denpasar
# 5238           610              Jakarta - Pangkal Pinang
#
#                 aircraft_type registration       cn_ln  \
# 4695  McDonnell-Douglas MD-82       PK-LMN  49189/1173
# 5104         Boeing B-737-8GP       PK-LKS  38728/4350
# 5238         Boeing 737-MAX 8       PK-LQP  43000/7058
#
#                               aboard                      fatalities ground  \
# 4695  163   (passengers:156  crew:7)    25   (passengers:23  crew:2)      0
# 5104  108   (passengers:101  crew:7)      0   (passengers:0  crew:0)      0
# ...

# %%
route
